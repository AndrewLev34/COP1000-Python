# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewLev34/COP1000-Python/blob/main/COP1000_Module01_HelloPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Includes at least four print statements.
includes at least one comment.
runs without syntax errors.
"""
#displays a welcome
print("hello class")

#displays a short intro
print("My name is Andrew Leverette.")

#displays my academic career
print("I want to earn a data science degree from UF")

#displays something I hope to learn in python
print("I hope to learn the fundamentals of python so that I'm prepared for future classes")

#displays a closing
print("goodbye class")
# Out:
# hello class
# My name is Andrew Leverette.
# I want to earn a data science degree from UF
# I hope to learn the fundamentals of python so that I'm prepared for future classes
# goodbye class
