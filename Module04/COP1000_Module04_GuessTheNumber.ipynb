# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewLev34/COP1000-Python/blob/main/Module04/COP1000_Module04_GuessTheNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#use these lines
#import random
#secret_number = random.randint(1, 20)

import random
secret_number = random.randint(1,20)

guess_count = 0

print("Welcome to Guess the Number!")
print()
print("I am thinking of a number between 1 and 20.")
print()

while True:
  guess = int(input("Take a guess:"))
  guess_count += 1

  if guess < secret_number:
    print("Too low. Try Again.")
  elif guess > secret_number:
    print("Too high. Try Again.")
  else:
    print("Correct!")
    print(f"You guessed the number in {guess_count} attempts.")
    break
# Out:
# Welcome to Guess the Number!
#
# I am thinking of a number between 1 and 20.
#
# Take a guess:20
# Too high. Try Again.
# Take a guess:1
# Too low. Try Again.
# Take a guess:20
# Too high. Try Again.
# Take a guess:10
# Too low. Try Again.
# Take a guess:15
# Correct!
# You guessed the number in 5 attempts.
