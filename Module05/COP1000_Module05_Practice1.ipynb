# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewLev34/COP1000-Python/blob/main/Module05/COP1000_Module05_Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def welcome():
    print("""Welcome to COP1000!
Python functions help organize programs!""")

welcome()
# Out:
# Welcome to COP1000!
# Python functions help organize programs!

# %%
def show_message():
    print("Practice makes progress!")

show_message()
show_message()
show_message()
# Out:
# Practice makes progress!
# Practice makes progress!
# Practice makes progress!

# %%
def show_header():
    print("----------")

def show_course():
    print("""COP1000.
Intro to Python.""")

def show_footer():
    print("----------")

show_header()
show_course()
show_footer()
# Out:
# ----------
# COP1000.
# Intro to Python.
# ----------

# %%
def greet(name):
    print(f"Hello, {name}!")

greet("Andrew")
greet("Mark")
greet("Dan")
# Out:
# Hello, Andrew!
# Hello, Mark!
# Hello, Dan!

# %%
def student_info(name, major):
    print(f"{name} is studying {major}.")

student_info("Andrew", "Data Science")
student_info("Tim", "Physics")
# Out:
# Andrew is studying Data Science.
# Tim is studying Physics.

# %%
def student_info(name, topic):
    name = input("Enter Your name here:")
    topic = input("Enter your favorite topic:")
    print(f"{name}'s favorite topic so far is {topic}.")

student_info("name", "topic")
# Out:
# Enter Your name here:Andrew
# Enter your favorite topic:function calling
# Andrew's favorite topic so far is function calling.

# %%
def title():
    print("Program Test.")

def message():
    print("This is a test to see if my code works.")

def closing():
    print("If all lines are printed without errors than this code works.")

title()
message()
closing()
# Out:
# Program Test.
# This is a test to see if my code works.
# If all lines are printed without errors than this code works.
