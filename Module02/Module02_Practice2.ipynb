# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewLev34/COP1000-Python/blob/main/Module01/COP1000_Module02_Practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("enter name here:")

print(f"Hello, {name} welcome to Python!")
# Out:
# enter name here:Andrew
# Hello, Andrew welcome to Python!

# %%
name = input("enter name:")
city = input("enter city of residence:")
food = input("enter favortie food:")

print(f"{name} lives in {city} and likes {food}")
# Out:
# enter name:Andrew
# enter city of residence:Fleming Island
# enter favortie food:Steak
# Andrew lives in Fleming Island and likes Steak

# %%
age = int(input("enter your age:"))

print(f"You are currently {age}")
print(f"Next year you will be {age + 1}")
# Out:
# enter your age:19
# You are currently 19
# Next year you will be 20

# %%
Num1 = int(input("enter first number:"))
Num2 = int(input("enter second number:"))

print(f"{Num1 + Num2}")
# Out:
# enter first number:17
# enter second number:5
# 22

# %%
Item = input("enter item name:")
Price = float(input("enter item price:"))
Quantity = int(input("enter item quantity:"))

print(f"""Purchase Summary
Item: {Item}
Price: ${Price}
Quantity: {Quantity}
Total Cost: ${Price * Quantity:.2f}""")
# Out:
# enter item name:Golf Balls
# enter item price:2.92
# enter item quantity:12
# Purchase Summary
# Item: Golf Balls
# Price: $2.92
# Quantity: 12
# Total Cost: $35.04

# %%
Hours_Worked = int(input("enter hours worked:"))
Wage = float(input("enter pay rate:"))

print(f"""Hours Worked: {Hours_Worked}
      Wage: ${Wage}

      Gross Pay: ${Hours_Worked * Wage:.2f}""")
# Out:
# enter hours worked:27
# enter pay rate:15.25
# Hours Worked: 27
#       Wage: $15.25
#
#       Gross Pay: $411.75
