# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewLev34/COP1000-Python/blob/main/COP1000_Module02_Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
First_name = "Andrew"
Gpa = 3.7
age = 19
is_student = True

print(First_name)
print(Gpa)
print(age)
print(is_student)
# Out:
# Andrew
# 3.7
# 19
# True

# %%
print(type(First_name))
print(type(Gpa))
print(type(age))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>

# %%
score = 75

print(score)

score = 90

print(score)
# Out:
# 75
# 90

# %%
number1 = 20
number2 = 5

print(number1 + number2)
print(number1 - number2)
print(number1 * number2)
print(number1 / number2)
# Out:
# 25
# 15
# 100
# 4.0

# %%
First_name = "Andrew"
Last_name = "Leverette"
academic_interest = "Data science"

print(f"My name is {First_name} {Last_name} and I am interested in {academic_interest}")
# Out:
# My name is Andrew Leverette and I am interested in Data science

# %%
#Student Profile

Name = "Andrew Leverette"
Course = "COP1000"
Current_grade = 100
Completed_assignments = 3
enrollment_status = True

print("Student Record")
print(f"Name:{Name}")
print(f"Course:{Course}")
print(f"Current Grade:{Current_grade}")
print(f"Completed Assignments:{Completed_assignments}")
print(f"Currently Enrolled:{enrollment_status}")
# Out:
# Student Record
# Name:Andrew Leverette
# Course:COP1000
# Current Grade:100
# Completed Assignments:3
# Currently Enrolled:True
